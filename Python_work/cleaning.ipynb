# %%
import pandas as pd
import numpy as np
import janitor

# %% [markdown]
# ## Cleaning PHS code and labels .csv

# %%
council_area_codes = pd.read_csv("../raw_data/dz2001_codes_and_labels_21042020.csv")
council_area_codes
# Out:
#        DataZone DataZoneName    IntZone        IntZoneName         CA  \
# 0     S01000001          NaN  S02000003             Culter  S12000033
# 1     S01000002          NaN  S02000001         Cove South  S12000033
# 2     S01000003          NaN  S02000001         Cove South  S12000033
# 3     S01000004          NaN  S02000001         Cove South  S12000033
# 4     S01000005          NaN  S02000003             Culter  S12000033
# ...         ...          ...        ...                ...        ...
# 6500  S01006501          NaN  S02001234   Linlithgow North  S12000040
# 6501  S01006502          NaN  S02001234   Linlithgow North  S12000040
# 6502  S01006503          NaN  S02001234   Linlithgow North  S12000040
# 6503  S01006504          NaN  S02001234   Linlithgow North  S12000040
# 6504  S01006505          NaN  S02001235  Linlithgow Bridge  S12000040
#
#              CAName       HSCP       HSCPName         HB        HBName  \
# 0     Aberdeen City  S37000001  Aberdeen City  S08000020  NHS Grampian
# 1     Aberdeen City  S37000001  Aberdeen City  S08000020  NHS Grampian
# 2     Aberdeen City  S37000001  Aberdeen City  S08000020  NHS Grampian
# 3     Aberdeen City  S37000001  Aberdeen City  S08000020  NHS Grampian
# 4     Aberdeen City  S37000001  Aberdeen City  S08000020  NHS Grampian
# ...             ...        ...            ...        ...           ...
# 6500   West Lothian  S37000030   West Lothian  S08000024   NHS Lothian
# 6501   West Lothian  S37000030   West Lothian  S08000024   NHS Lothian
# 6502   West Lothian  S37000030   West Lothian  S08000024   NHS Lothian
# 6503   West Lothian  S37000030   West Lothian  S08000024   NHS Lothian
# 6504   West Lothian  S37000030   West Lothian  S08000024   NHS Lothian
#
#         Country
# 0     S92000003
# 1     S92000003
# 2     S92000003
# 3     S92000003
# 4     S92000003
# ...         ...
# 6500  S92000003
# 6501  S92000003
# 6502  S92000003
# 6503  S92000003
# 6504  S92000003
#
# [6505 rows x 11 columns]

# %%
area_codes = council_area_codes[["CA", "CAName"]].copy()
area_codes
# Out:
#              CA         CAName
# 0     S12000033  Aberdeen City
# 1     S12000033  Aberdeen City
# 2     S12000033  Aberdeen City
# 3     S12000033  Aberdeen City
# 4     S12000033  Aberdeen City
# ...         ...            ...
# 6500  S12000040   West Lothian
# 6501  S12000040   West Lothian
# 6502  S12000040   West Lothian
# 6503  S12000040   West Lothian
# 6504  S12000040   West Lothian
#
# [6505 rows x 2 columns]

# %%
council_codes = (
    area_codes
    .drop_duplicates()
    .reset_index(drop=True)
    .rename(columns={"CA": "area_codes", 
                     "CAName": "council_name"})
)
council_codes
# Out:
#    area_codes           council_name
# 0   S12000033          Aberdeen City
# 1   S12000034          Aberdeenshire
# 2   S12000041                  Angus
# 3   S12000035        Argyll and Bute
# 4   S12000005       Clackmannanshire
# 5   S12000006  Dumfries and Galloway
# 6   S12000042            Dundee City
# 7   S12000008          East Ayrshire
# 8   S12000045    East Dunbartonshire
# 9   S12000010           East Lothian
# 10  S12000011      East Renfrewshire
# 11  S12000036      City of Edinburgh
# 12  S12000013     Na h-Eileanan Siar
# 13  S12000014                Falkirk
# 14  S12000047                   Fife
# 15  S12000049           Glasgow City
# 16  S12000017               Highland
# 17  S12000018             Inverclyde
# 18  S12000019             Midlothian
# 19  S12000020                  Moray
# 20  S12000021         North Ayrshire
# 21  S12000050      North Lanarkshire
# 22  S12000023         Orkney Islands
# 23  S12000048      Perth and Kinross
# 24  S12000038           Renfrewshire
# 25  S12000026       Scottish Borders
# 26  S12000027       Shetland Islands
# 27  S12000028         South Ayrshire
# 28  S12000029      South Lanarkshire
# 29  S12000030               Stirling
# 30  S12000039    West Dunbartonshire
# 31  S12000040           West Lothian

# %%
scotland = pd.DataFrame([["S92000003", "Scotland"]], 
                        columns=['area_codes', 'council_name'])

council_codes = (
    council_codes
    .append(scotland)
    .reset_index(drop=True)
    .copy()
)

# %%
council_codes
# Out:
#    area_codes           council_name
# 0   S12000033          Aberdeen City
# 1   S12000034          Aberdeenshire
# 2   S12000041                  Angus
# 3   S12000035        Argyll and Bute
# 4   S12000005       Clackmannanshire
# 5   S12000006  Dumfries and Galloway
# 6   S12000042            Dundee City
# 7   S12000008          East Ayrshire
# 8   S12000045    East Dunbartonshire
# 9   S12000010           East Lothian
# 10  S12000011      East Renfrewshire
# 11  S12000036      City of Edinburgh
# 12  S12000013     Na h-Eileanan Siar
# 13  S12000014                Falkirk
# 14  S12000047                   Fife
# 15  S12000049           Glasgow City
# 16  S12000017               Highland
# 17  S12000018             Inverclyde
# 18  S12000019             Midlothian
# 19  S12000020                  Moray
# 20  S12000021         North Ayrshire
# 21  S12000050      North Lanarkshire
# 22  S12000023         Orkney Islands
# 23  S12000048      Perth and Kinross
# 24  S12000038           Renfrewshire
# 25  S12000026       Scottish Borders
# 26  S12000027       Shetland Islands
# 27  S12000028         South Ayrshire
# 28  S12000029      South Lanarkshire
# 29  S12000030               Stirling
# 30  S12000039    West Dunbartonshire
# 31  S12000040           West Lothian
# 32  S92000003               Scotland

# %% [markdown]
# <br>

# %% [markdown]
# ## Cleaning scot. gov. green_spaces.csv

# %%
green_spaces = pd.read_csv("../raw_data/green_spaces.csv").clean_names()
green_spaces
# Out:
#       featurecode  datecode                          measurement  \
# 0       S12000026      2013  95% Lower Confidence Limit, Percent
# 1       S12000045      2017                              Percent
# 2       S12000026      2014  95% Upper Confidence Limit, Percent
# 3       S12000026      2017  95% Upper Confidence Limit, Percent
# 4       S12000026      2017  95% Upper Confidence Limit, Percent
# ...           ...       ...                                  ...
# 38446   S92000003      2018                              Percent
# 38447   S92000003      2018  95% Lower Confidence Limit, Percent
# 38448   S92000003      2019  95% Upper Confidence Limit, Percent
# 38449   S92000003      2014  95% Lower Confidence Limit, Percent
# 38450   S12000036      2018  95% Upper Confidence Limit, Percent
#
#                    units  value distance_to_nearest_green_or_blue_space  age  \
# 0      Percent Of Adults   71.0                 A 5 minute walk or less  All
# 1      Percent Of Adults   59.0                 A 5 minute walk or less  All
# 2      Percent Of Adults   86.9                 A 5 minute walk or less  All
# 3      Percent Of Adults   80.9                 A 5 minute walk or less  All
# 4      Percent Of Adults   79.6                 A 5 minute walk or less  All
# ...                  ...    ...                                     ...  ...
# 38446  Percent Of Adults   26.0               Within a 6-10 minute walk  All
# 38447  Percent Of Adults   20.4               Within a 6-10 minute walk  All
# 38448  Percent Of Adults    7.8                              Don't Know  All
# 38449  Percent Of Adults   15.8               Within a 6-10 minute walk  All
# 38450  Percent Of Adults   36.1               Within a 6-10 minute walk  All
#
#       gender urban_rural_classification simd_quintiles type_of_tenure  \
# 0        All                        All            All            All
# 1        All                        All            All            All
# 2        All                        All            All            All
# 3        All                        All            All            All
# 4        All                        All            All            All
# ...      ...                        ...            ...            ...
# 38446    All                        All            All            All
# 38447    All                        All            All            All
# 38448    All                        All            All            All
# 38449    All                        All            All            All
# 38450    All                        All            All            All
#
#       household_type ethnicity
# 0                All       All
# 1         Pensioners       All
# 2                All       All
# 3                All       All
# 4         Pensioners       All
# ...              ...       ...
# 38446            All     Other
# 38447            All     Other
# 38448            All     Other
# 38449            All     Other
# 38450            All     Other
#
# [38451 rows x 13 columns]

# %%
green_spaces.isna().sum()
# Out:
# featurecode                                0
# datecode                                   0
# measurement                                0
# units                                      0
# value                                      0
# distance_to_nearest_green_or_blue_space    0
# age                                        0
# gender                                     0
# urban_rural_classification                 0
# simd_quintiles                             0
# type_of_tenure                             0
# household_type                             0
# ethnicity                                  0
# dtype: int64

# %%
# (
#     green_spaces
#     .clean_names()
# )

# %%
green_spaces = (
    green_spaces
   .rename(columns={"featurecode":"area_codes",
                    "datecode":"year",
                    "distance_to_nearest_green_or_blue_space":"walking_distance_to_nearest_greenspace",
                    "urban_rural_classification":"urban_rural"})
)

green_spaces
# Out:
#       area_codes  year                          measurement  \
# 0      S12000026  2013  95% Lower Confidence Limit, Percent
# 1      S12000045  2017                              Percent
# 2      S12000026  2014  95% Upper Confidence Limit, Percent
# 3      S12000026  2017  95% Upper Confidence Limit, Percent
# 4      S12000026  2017  95% Upper Confidence Limit, Percent
# ...          ...   ...                                  ...
# 38446  S92000003  2018                              Percent
# 38447  S92000003  2018  95% Lower Confidence Limit, Percent
# 38448  S92000003  2019  95% Upper Confidence Limit, Percent
# 38449  S92000003  2014  95% Lower Confidence Limit, Percent
# 38450  S12000036  2018  95% Upper Confidence Limit, Percent
#
#                    units  value walking_distance_to_nearest_greenspace  age  \
# 0      Percent Of Adults   71.0                A 5 minute walk or less  All
# 1      Percent Of Adults   59.0                A 5 minute walk or less  All
# 2      Percent Of Adults   86.9                A 5 minute walk or less  All
# 3      Percent Of Adults   80.9                A 5 minute walk or less  All
# 4      Percent Of Adults   79.6                A 5 minute walk or less  All
# ...                  ...    ...                                    ...  ...
# 38446  Percent Of Adults   26.0              Within a 6-10 minute walk  All
# 38447  Percent Of Adults   20.4              Within a 6-10 minute walk  All
# 38448  Percent Of Adults    7.8                             Don't Know  All
# 38449  Percent Of Adults   15.8              Within a 6-10 minute walk  All
# 38450  Percent Of Adults   36.1              Within a 6-10 minute walk  All
#
#       gender urban_rural simd_quintiles type_of_tenure household_type  \
# 0        All         All            All            All            All
# 1        All         All            All            All     Pensioners
# 2        All         All            All            All            All
# 3        All         All            All            All            All
# 4        All         All            All            All     Pensioners
# ...      ...         ...            ...            ...            ...
# 38446    All         All            All            All            All
# 38447    All         All            All            All            All
# 38448    All         All            All            All            All
# 38449    All         All            All            All            All
# 38450    All         All            All            All            All
#
#       ethnicity
# 0           All
# 1           All
# 2           All
# 3           All
# 4           All
# ...         ...
# 38446     Other
# 38447     Other
# 38448     Other
# 38449     Other
# 38450     Other
#
# [38451 rows x 13 columns]

# %%
# green_spaces.columns = (
#     green_spaces
#     .columns.str.lower()
#     .str.replace(' ','_')
# )

# green_spaces = (green_spaces
#                 .rename(columns={"featurecode":"area_codes",
#                     "datecode":"year",
#                     "distance_to_nearest_green_or_blue_space":"distance_from_household",
#                     "urban_rural_classification":"urban_rural"})
#                )

# green_spaces

# %%
green = (
    green_spaces.merge(council_codes, 
                       how='inner', 
                       on='area_codes')
)

column_to_move = green.pop("council_name")

# insert column with insert(location, column_name, column_value)

green.insert(1, "council_name", column_to_move)

green
# Out:
#       area_codes        council_name  year  \
# 0      S12000026    Scottish Borders  2013
# 1      S12000026    Scottish Borders  2014
# 2      S12000026    Scottish Borders  2017
# 3      S12000026    Scottish Borders  2017
# 4      S12000026    Scottish Borders  2014
# ...          ...                 ...   ...
# 38446  S12000013  Na h-Eileanan Siar  2016
# 38447  S12000013  Na h-Eileanan Siar  2017
# 38448  S12000013  Na h-Eileanan Siar  2018
# 38449  S12000013  Na h-Eileanan Siar  2018
# 38450  S12000013  Na h-Eileanan Siar  2017
#
#                                measurement              units  value  \
# 0      95% Lower Confidence Limit, Percent  Percent Of Adults   71.0
# 1      95% Upper Confidence Limit, Percent  Percent Of Adults   86.9
# 2      95% Upper Confidence Limit, Percent  Percent Of Adults   80.9
# 3      95% Upper Confidence Limit, Percent  Percent Of Adults   79.6
# 4      95% Lower Confidence Limit, Percent  Percent Of Adults   76.8
# ...                                    ...                ...    ...
# 38446                              Percent  Percent Of Adults    1.0
# 38447  95% Lower Confidence Limit, Percent  Percent Of Adults    0.0
# 38448                              Percent  Percent Of Adults    2.0
# 38449  95% Upper Confidence Limit, Percent  Percent Of Adults    4.2
# 38450  95% Lower Confidence Limit, Percent  Percent Of Adults   18.7
#
#       walking_distance_to_nearest_greenspace  age gender urban_rural  \
# 0                    A 5 minute walk or less  All    All         All
# 1                    A 5 minute walk or less  All    All         All
# 2                    A 5 minute walk or less  All    All         All
# 3                    A 5 minute walk or less  All    All         All
# 4                    A 5 minute walk or less  All    All         All
# ...                                      ...  ...    ...         ...
# 38446                             Don't Know  All    All         All
# 38447                             Don't Know  All    All         All
# 38448              An 11 minute walk or more  All    All         All
# 38449              An 11 minute walk or more  All    All         All
# 38450              Within a 6-10 minute walk  All    All         All
#
#       simd_quintiles type_of_tenure household_type ethnicity
# 0                All            All            All       All
# 1                All            All            All       All
# 2                All            All            All       All
# 3                All            All     Pensioners       All
# 4                All            All            All       All
# ...              ...            ...            ...       ...
# 38446            All            All            All     White
# 38447            All            All            All     White
# 38448            All            All            All     White
# 38449            All            All            All     White
# 38450            All            All            All     White
#
# [38451 rows x 14 columns]

# %%
green.isna().sum()
# Out:
# area_codes                                0
# council_name                              0
# year                                      0
# measurement                               0
# units                                     0
# value                                     0
# walking_distance_to_nearest_greenspace    0
# age                                       0
# gender                                    0
# urban_rural                               0
# simd_quintiles                            0
# type_of_tenure                            0
# household_type                            0
# ethnicity                                 0
# dtype: int64

# %%
green.type_of_tenure.unique()
# Out:
# array(['All', 'Owned Outright', 'Social Rented', 'Owned Mortgage/Loan',
#        'Private Rented', 'Other'], dtype=object)

# %%
green.ethnicity.unique()
# Out:
# array(['All', 'White', 'Other'], dtype=object)

# %%
green.household_type.unique()
# Out:
# array(['All', 'Pensioners', 'Adults', 'With Children'], dtype=object)

# %%
green.simd_quintiles.unique()
# Out:
# array(['All', '80% least deprived', '20% most deprived'], dtype=object)

# %%
green.urban_rural.unique()
# Out:
# array(['All', 'Urban', 'Rural'], dtype=object)

# %%
green.gender.unique()
# Out:
# array(['All', 'Female', 'Male'], dtype=object)

# %%
green.age.unique()
# Out:
# array(['All', '35-64 years', '65 years and over', '16-34 years'],
#       dtype=object)

# %%
green.walking_distance_to_nearest_greenspace.unique()
# Out:
# array(['A 5 minute walk or less', "Don't Know",
#        'An 11 minute walk or more', 'Within a 6-10 minute walk'],
#       dtype=object)

# %%
green.dtypes
# Out:
# area_codes                                 object
# council_name                               object
# year                                        int64
# measurement                                object
# units                                      object
# value                                     float64
# walking_distance_to_nearest_greenspace     object
# age                                        object
# gender                                     object
# urban_rural                                object
# simd_quintiles                             object
# type_of_tenure                             object
# household_type                             object
# ethnicity                                  object
# dtype: object

# %%
import os  

os.makedirs('../clean_data', exist_ok=True)  

green.to_csv('../clean_data/cleaned_green_spaces.csv', index = False)

# %% [markdown]
# <br>

# %% [markdown]
# ## Cleaning scot. gov. community_belonging.csv

# %%
community_belonging = pd.read_csv("../raw_data/community_belonging.csv").clean_names()
community_belonging
# Out:
#       featurecode  datecode                          measurement  \
# 0       S12000040      2018  95% Upper Confidence Limit, Percent
# 1       S12000029      2018  95% Lower Confidence Limit, Percent
# 2       S12000040      2018  95% Lower Confidence Limit, Percent
# 3       S12000049      2014  95% Upper Confidence Limit, Percent
# 4       S12000049      2014  95% Lower Confidence Limit, Percent
# ...           ...       ...                                  ...
# 43606   S12000049      2013                              Percent
# 43607   S92000003      2019                              Percent
# 43608   S12000042      2014                              Percent
# 43609   S12000042      2014  95% Lower Confidence Limit, Percent
# 43610   S12000049      2016                              Percent
#
#                    units  value  community_belonging gender  \
# 0      Percent Of Adults   66.6        Very strongly    All
# 1      Percent Of Adults   29.3        Very strongly    All
# 2      Percent Of Adults   40.2        Very strongly    All
# 3      Percent Of Adults   50.9      Fairly strongly    All
# 4      Percent Of Adults   33.6      Fairly strongly    All
# ...                  ...    ...                  ...    ...
# 43606  Percent Of Adults   28.0    Not very strongly    All
# 43607  Percent Of Adults   26.0    Not very strongly    All
# 43608  Percent Of Adults   18.0  Not at all strongly    All
# 43609  Percent Of Adults    7.6  Not at all strongly    All
# 43610  Percent Of Adults    8.0  Not at all strongly    All
#
#       urban_rural_classification simd_quintiles  type_of_tenure  \
# 0                            All            All             All
# 1                            All            All             All
# 2                            All            All             All
# 3                            All            All             All
# 4                            All            All             All
# ...                          ...            ...             ...
# 43606                        All            All  Private Rented
# 43607                        All            All  Private Rented
# 43608                        All            All  Private Rented
# 43609                        All            All  Private Rented
# 43610                        All            All  Private Rented
#
#       household_type ethnicity walking_distance_to_nearest_greenspace
# 0                All       All                   More than 10 minutes
# 1                All       All                   More than 10 minutes
# 2                All       All                   More than 10 minutes
# 3                All       All                   More than 10 minutes
# 4                All       All                   More than 10 minutes
# ...              ...       ...                                    ...
# 43606            All       All                                    All
# 43607            All       All                                    All
# 43608            All       All                                    All
# 43609            All       All                                    All
# 43610            All       All                                    All
#
# [43611 rows x 13 columns]

# %%
community = (
    community_belonging
   .rename(columns={"featurecode":"area_codes",
                    "datecode":"year",
                    "urban_rural_classification":"urban_rural"})
)

community
# Out:
#       area_codes  year                          measurement  \
# 0      S12000040  2018  95% Upper Confidence Limit, Percent
# 1      S12000029  2018  95% Lower Confidence Limit, Percent
# 2      S12000040  2018  95% Lower Confidence Limit, Percent
# 3      S12000049  2014  95% Upper Confidence Limit, Percent
# 4      S12000049  2014  95% Lower Confidence Limit, Percent
# ...          ...   ...                                  ...
# 43606  S12000049  2013                              Percent
# 43607  S92000003  2019                              Percent
# 43608  S12000042  2014                              Percent
# 43609  S12000042  2014  95% Lower Confidence Limit, Percent
# 43610  S12000049  2016                              Percent
#
#                    units  value  community_belonging gender urban_rural  \
# 0      Percent Of Adults   66.6        Very strongly    All         All
# 1      Percent Of Adults   29.3        Very strongly    All         All
# 2      Percent Of Adults   40.2        Very strongly    All         All
# 3      Percent Of Adults   50.9      Fairly strongly    All         All
# 4      Percent Of Adults   33.6      Fairly strongly    All         All
# ...                  ...    ...                  ...    ...         ...
# 43606  Percent Of Adults   28.0    Not very strongly    All         All
# 43607  Percent Of Adults   26.0    Not very strongly    All         All
# 43608  Percent Of Adults   18.0  Not at all strongly    All         All
# 43609  Percent Of Adults    7.6  Not at all strongly    All         All
# 43610  Percent Of Adults    8.0  Not at all strongly    All         All
#
#       simd_quintiles  type_of_tenure household_type ethnicity  \
# 0                All             All            All       All
# 1                All             All            All       All
# 2                All             All            All       All
# 3                All             All            All       All
# 4                All             All            All       All
# ...              ...             ...            ...       ...
# 43606            All  Private Rented            All       All
# 43607            All  Private Rented            All       All
# 43608            All  Private Rented            All       All
# 43609            All  Private Rented            All       All
# 43610            All  Private Rented            All       All
#
#       walking_distance_to_nearest_greenspace
# 0                       More than 10 minutes
# 1                       More than 10 minutes
# 2                       More than 10 minutes
# 3                       More than 10 minutes
# 4                       More than 10 minutes
# ...                                      ...
# 43606                                    All
# 43607                                    All
# 43608                                    All
# 43609                                    All
# 43610                                    All
#
# [43611 rows x 13 columns]

# %%
community = (
    community.merge(council_codes, 
                       how='inner', 
                       on='area_codes')
)

column_to_move = community.pop("council_name")

# insert column with insert(location, column_name, column_value)

community.insert(1, "council_name", column_to_move)

community
# Out:
#       area_codes           council_name  year  \
# 0      S12000040           West Lothian  2018
# 1      S12000040           West Lothian  2018
# 2      S12000040           West Lothian  2017
# 3      S12000040           West Lothian  2017
# 4      S12000040           West Lothian  2018
# ...          ...                    ...   ...
# 43606  S12000006  Dumfries and Galloway  2018
# 43607  S12000006  Dumfries and Galloway  2018
# 43608  S12000006  Dumfries and Galloway  2019
# 43609  S12000006  Dumfries and Galloway  2018
# 43610  S12000006  Dumfries and Galloway  2018
#
#                                measurement              units  value  \
# 0      95% Upper Confidence Limit, Percent  Percent Of Adults   66.6
# 1      95% Lower Confidence Limit, Percent  Percent Of Adults   40.2
# 2                                  Percent  Percent Of Adults   43.0
# 3      95% Lower Confidence Limit, Percent  Percent Of Adults   29.3
# 4                                  Percent  Percent Of Adults   53.0
# ...                                    ...                ...    ...
# 43606                              Percent  Percent Of Adults    9.0
# 43607  95% Upper Confidence Limit, Percent  Percent Of Adults   69.3
# 43608  95% Upper Confidence Limit, Percent  Percent Of Adults   21.8
# 43609  95% Lower Confidence Limit, Percent  Percent Of Adults    0.0
# 43610  95% Upper Confidence Limit, Percent  Percent Of Adults   14.8
#
#        community_belonging gender urban_rural simd_quintiles type_of_tenure  \
# 0            Very strongly    All         All            All            All
# 1            Very strongly    All         All            All            All
# 2          Fairly strongly    All         All            All            All
# 3          Fairly strongly    All         All            All            All
# 4            Very strongly    All         All            All            All
# ...                    ...    ...         ...            ...            ...
# 43606  Not at all strongly    All         All            All  Social Rented
# 43607      Fairly strongly    All         All            All  Social Rented
# 43608  Not at all strongly    All         All            All  Social Rented
# 43609    Not very strongly    All         All            All  Social Rented
# 43610    Not very strongly    All         All            All  Social Rented
#
#       household_type ethnicity walking_distance_to_nearest_greenspace
# 0                All       All                   More than 10 minutes
# 1                All       All                   More than 10 minutes
# 2                All       All                   More than 10 minutes
# 3                All       All                   More than 10 minutes
# 4                All       All                   More than 10 minutes
# ...              ...       ...                                    ...
# 43606            All       All                                    All
# 43607            All       All                                    All
# 43608            All       All                                    All
# 43609            All       All                                    All
# 43610            All       All                                    All
#
# [43611 rows x 14 columns]

# %%
community.isna().sum()
# Out:
# area_codes                                0
# council_name                              0
# year                                      0
# measurement                               0
# units                                     0
# value                                     0
# community_belonging                       0
# gender                                    0
# urban_rural                               0
# simd_quintiles                            0
# type_of_tenure                            0
# household_type                            0
# ethnicity                                 0
# walking_distance_to_nearest_greenspace    0
# dtype: int64

# %%
community.community_belonging.unique()
# Out:
# array(['Very strongly', 'Fairly strongly', 'Not at all strongly',
#        'Not very strongly', "Don't know"], dtype=object)

# %%
os.makedirs('../clean_data', exist_ok=True)  

community.to_csv('../clean_data/cleaned_community_belonging.csv', index = False)

# %% [markdown]
# <br>

# %% [markdown]
# ## Cleaning scot. gov. neighbourhood_rating.csv

# %%
neighbourhood_rating = pd.read_csv("../raw_data/neighbourhood_rating.csv").clean_names()
neighbourhood_rating
# Out:
#       featurecode  datecode                          measurement  \
# 0       S12000033      2018  95% Lower Confidence Limit, Percent
# 1       S12000039      2016  95% Lower Confidence Limit, Percent
# 2       S12000039      2016  95% Upper Confidence Limit, Percent
# 3       S12000049      2013  95% Lower Confidence Limit, Percent
# 4       S12000036      2018  95% Upper Confidence Limit, Percent
# ...           ...       ...                                  ...
# 38050   S12000035      2019  95% Upper Confidence Limit, Percent
# 38051   S12000039      2017  95% Lower Confidence Limit, Percent
# 38052   S12000040      2017  95% Upper Confidence Limit, Percent
# 38053   S12000038      2019  95% Upper Confidence Limit, Percent
# 38054   S12000035      2013  95% Lower Confidence Limit, Percent
#
#                    units  value neighbourhood_rating gender  \
# 0      Percent Of Adults   34.2            Very good    All
# 1      Percent Of Adults   35.1            Very good    All
# 2      Percent Of Adults   63.3            Very good    All
# 3      Percent Of Adults    1.5            Very poor    All
# 4      Percent Of Adults   11.9          Fairly poor    All
# ...                  ...    ...                  ...    ...
# 38050  Percent Of Adults   29.7          Fairly good    All
# 38051  Percent Of Adults    0.0            Very poor    All
# 38052  Percent Of Adults    4.3            Very poor    All
# 38053  Percent Of Adults   46.1          Fairly good    All
# 38054  Percent Of Adults    0.0          Fairly poor    All
#
#       urban_rural_classification simd_quintiles  type_of_tenure  \
# 0                            All            All             All
# 1                            All            All             All
# 2                            All            All             All
# 3                            All            All             All
# 4                            All            All             All
# ...                          ...            ...             ...
# 38050                        All            All  Owned Outright
# 38051                        All            All   Social Rented
# 38052                        All            All   Social Rented
# 38053                        All            All  Owned Outright
# 38054                        All            All  Owned Outright
#
#       household_type ethnicity walking_distance_to_nearest_greenspace
# 0                All       All                   More than 10 minutes
# 1                All       All                   More than 10 minutes
# 2                All       All                   More than 10 minutes
# 3                All       All                   More than 10 minutes
# 4                All       All                   More than 10 minutes
# ...              ...       ...                                    ...
# 38050            All       All                                    All
# 38051            All       All                                    All
# 38052            All       All                                    All
# 38053            All       All                                    All
# 38054            All       All                                    All
#
# [38055 rows x 13 columns]

# %%
neighbourhood = (
    neighbourhood_rating
   .rename(columns={"featurecode":"area_codes",
                    "datecode":"year",
                    "distance_to_nearest_green_or_blue_space":"walking_distance_to_nearest_greenspace",
                    "urban_rural_classification":"urban_rural"})
)

neighbourhood
# Out:
#       area_codes  year                          measurement  \
# 0      S12000033  2018  95% Lower Confidence Limit, Percent
# 1      S12000039  2016  95% Lower Confidence Limit, Percent
# 2      S12000039  2016  95% Upper Confidence Limit, Percent
# 3      S12000049  2013  95% Lower Confidence Limit, Percent
# 4      S12000036  2018  95% Upper Confidence Limit, Percent
# ...          ...   ...                                  ...
# 38050  S12000035  2019  95% Upper Confidence Limit, Percent
# 38051  S12000039  2017  95% Lower Confidence Limit, Percent
# 38052  S12000040  2017  95% Upper Confidence Limit, Percent
# 38053  S12000038  2019  95% Upper Confidence Limit, Percent
# 38054  S12000035  2013  95% Lower Confidence Limit, Percent
#
#                    units  value neighbourhood_rating gender urban_rural  \
# 0      Percent Of Adults   34.2            Very good    All         All
# 1      Percent Of Adults   35.1            Very good    All         All
# 2      Percent Of Adults   63.3            Very good    All         All
# 3      Percent Of Adults    1.5            Very poor    All         All
# 4      Percent Of Adults   11.9          Fairly poor    All         All
# ...                  ...    ...                  ...    ...         ...
# 38050  Percent Of Adults   29.7          Fairly good    All         All
# 38051  Percent Of Adults    0.0            Very poor    All         All
# 38052  Percent Of Adults    4.3            Very poor    All         All
# 38053  Percent Of Adults   46.1          Fairly good    All         All
# 38054  Percent Of Adults    0.0          Fairly poor    All         All
#
#       simd_quintiles  type_of_tenure household_type ethnicity  \
# 0                All             All            All       All
# 1                All             All            All       All
# 2                All             All            All       All
# 3                All             All            All       All
# 4                All             All            All       All
# ...              ...             ...            ...       ...
# 38050            All  Owned Outright            All       All
# 38051            All   Social Rented            All       All
# 38052            All   Social Rented            All       All
# 38053            All  Owned Outright            All       All
# 38054            All  Owned Outright            All       All
#
#       walking_distance_to_nearest_greenspace
# 0                       More than 10 minutes
# 1                       More than 10 minutes
# 2                       More than 10 minutes
# 3                       More than 10 minutes
# 4                       More than 10 minutes
# ...                                      ...
# 38050                                    All
# 38051                                    All
# 38052                                    All
# 38053                                    All
# 38054                                    All
#
# [38055 rows x 13 columns]

# %%
neighbourhood.isna().sum()
# Out:
# area_codes                                0
# year                                      0
# measurement                               0
# units                                     0
# value                                     0
# neighbourhood_rating                      0
# gender                                    0
# urban_rural                               0
# simd_quintiles                            0
# type_of_tenure                            0
# household_type                            0
# ethnicity                                 0
# walking_distance_to_nearest_greenspace    0
# dtype: int64

# %%
neighbourhood= (
    neighbourhood.merge(council_codes, 
                       how='inner', 
                       on='area_codes')
)

column_to_move = neighbourhood.pop("council_name")

# insert column with insert(location, column_name, column_value)

neighbourhood.insert(1, "council_name", column_to_move)

neighbourhood
# Out:
#       area_codes      council_name  year                          measurement  \
# 0      S12000033     Aberdeen City  2018  95% Lower Confidence Limit, Percent
# 1      S12000033     Aberdeen City  2018  95% Upper Confidence Limit, Percent
# 2      S12000033     Aberdeen City  2013  95% Lower Confidence Limit, Percent
# 3      S12000033     Aberdeen City  2016  95% Upper Confidence Limit, Percent
# 4      S12000033     Aberdeen City  2017  95% Lower Confidence Limit, Percent
# ...          ...               ...   ...                                  ...
# 38050  S12000005  Clackmannanshire  2013  95% Lower Confidence Limit, Percent
# 38051  S12000005  Clackmannanshire  2019  95% Lower Confidence Limit, Percent
# 38052  S12000005  Clackmannanshire  2017  95% Upper Confidence Limit, Percent
# 38053  S12000005  Clackmannanshire  2014                              Percent
# 38054  S12000005  Clackmannanshire  2015  95% Lower Confidence Limit, Percent
#
#                    units  value neighbourhood_rating gender urban_rural  \
# 0      Percent Of Adults   34.2            Very good    All         All
# 1      Percent Of Adults   62.8            Very good    All         All
# 2      Percent Of Adults    0.0            Very poor    All         All
# 3      Percent Of Adults    7.8            Very poor    All         All
# 4      Percent Of Adults    0.0          Fairly poor    All         All
# ...                  ...    ...                  ...    ...         ...
# 38050  Percent Of Adults   32.9          Fairly good    All         All
# 38051  Percent Of Adults    0.0            Very poor    All         All
# 38052  Percent Of Adults    1.9          Fairly poor    All         All
# 38053  Percent Of Adults    3.0          Fairly poor    All         All
# 38054  Percent Of Adults    0.0          Fairly poor    All         All
#
#       simd_quintiles  type_of_tenure household_type ethnicity  \
# 0                All             All            All       All
# 1                All             All            All       All
# 2                All             All            All       All
# 3                All             All            All       All
# 4                All             All            All       All
# ...              ...             ...            ...       ...
# 38050            All  Owned Outright            All       All
# 38051            All  Owned Outright            All       All
# 38052            All  Owned Outright            All       All
# 38053            All  Owned Outright            All       All
# 38054            All  Owned Outright            All       All
#
#       walking_distance_to_nearest_greenspace
# 0                       More than 10 minutes
# 1                       More than 10 minutes
# 2                       More than 10 minutes
# 3                       More than 10 minutes
# 4                       More than 10 minutes
# ...                                      ...
# 38050                                    All
# 38051                                    All
# 38052                                    All
# 38053                                    All
# 38054                                    All
#
# [38055 rows x 14 columns]

# %%
neighbourhood.isna().sum()
# Out:
# area_codes                                0
# council_name                              0
# year                                      0
# measurement                               0
# units                                     0
# value                                     0
# neighbourhood_rating                      0
# gender                                    0
# urban_rural                               0
# simd_quintiles                            0
# type_of_tenure                            0
# household_type                            0
# ethnicity                                 0
# walking_distance_to_nearest_greenspace    0
# dtype: int64

# %%
neighbourhood.neighbourhood_rating.unique()
# Out:
# array(['Very good', 'Very poor', 'Fairly poor', 'Fairly good',
#        'No opinion'], dtype=object)

# %%
os.makedirs('../clean_data', exist_ok=True)  

neighbourhood.to_csv('../clean_data/cleaned_neighbourhood_rating.csv', index = False)
